# %% [markdown]
# Fastbook imports, can ignore it

# %% [markdown]
# Import everything from fastai.vision.all and use the URLs.PETS dataset

# %% [markdown]
# Use this regex to get the class names for the images '(.+)_\d+.jpg$'

# %% [markdown]
# Create a DataBlock and use presizing to augment the dataset. Resize the items to 460 and for batch transforms use the aug transforms function with size 224 and min_scale as 0.75

# %% [markdown]
# Create a dataloader and use show batch to test that it works

# %% [markdown]
# Use summary on the datablock

# %% [markdown]
# Create a vision learner with resnet34 and fine tune for 2 epochs

# %% [markdown]
# Plot the confusion matrix using ClassificationInterpretation

# %% [markdown]
# Check most_confused with atleast 5 values

# %% [markdown]
# Run learner using 0.1 as the learning rate

# %% [markdown]
# Use the lr_find function on an untrained learner and get the minimum and steep values to choose the appropriate learning rate

# %% [markdown]
# Fine tune for 2 epochs again using the new learning rate

# %% [markdown]
# Try using fit one cycle with three epochs

# %% [markdown]
# unfreeze the learner and run lr find again to choose a lr from a flat section and fine tune 6 more times

# %% [markdown]
# Train the model again from start with the first section training for 3 epochs and the second for 12, this time for the second section use the slice of the entire flat section for the learning rate.

# %% [markdown]
# run learn.recorder.plot_loss()
